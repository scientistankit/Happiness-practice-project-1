# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import scipy.stats as stats

df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#there is no null value

# %%
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
#there are 158 rows in the dataset
#the large difference between 75% and max shows the presence of outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    int64
#  1   Region                         158 non-null    int64
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(3)
# ...

# %%
df["Happiness Score"].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %% [markdown]
# # EDA
# univariate analysis

# %%
sn.countplot(df['Happiness Score']);

# %%
sn.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sn.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sn.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
 sn.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sn.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sn.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sn.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sn.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sn.boxplot(df["Happiness Score"])
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %%
sn.boxplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error'>

# %%
sn.boxplot(df["Economy (GDP per Capita)"])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)'>

# %%
sn.boxplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family'>

# %%
sn.boxplot(df["Health (Life Expectancy)"])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sn.boxplot(df["Freedom"])
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %%
sn.boxplot(df["Trust (Government Corruption)"])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sn.boxplot(df["Generosity"])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %%
sn.boxplot(df["Dystopia Residual"])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %% [markdown]
# Bivariates analysis

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Economy (GDP per Capita) and Standard Error')
sn.scatterplot(df['Economy (GDP per Capita)'],df['Standard Error'],hue=df["Happiness Score"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Family and Health (Life Expectancy)')
sn.scatterplot(df['Family'],df['Health (Life Expectancy)'],hue=df["Happiness Score"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Freedom and Trust (Government Corruption)')
sn.scatterplot(df['Freedom'],df['Trust (Government Corruption)'],hue=df["Happiness Score"]);

# %%
plt.figure(figsize=[10,6])
plt.title('Generosity and Dystopia Residual')
sn.scatterplot(df['Generosity'],df['Dystopia Residual'],hue=df["Happiness Score"]);

# %%
sn.pairplot(df,hue="Happiness Score")

# %%
cor=df.corr()

# %%
cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
sn.heatmap(cor,annot=True,linewidths=2,linecolor='green')
# Out:
# <AxesSubplot:>

# %%
dfcor=df.corr()
sn.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
sn.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
#Happiness score depends strongly on economy,family and health.
#it also has a good correlation with freedom,trust and generosity
#it is poorly correlated with country
#it is negatively related with region and standard error

# %% [markdown]
# Lable encoder

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Country"]=LE.fit_transform(df["Country"])
df["Region"]=LE.fit_transform(df["Region"])

# %%
df["Country"].unique()
df["Region"].unique()
# Out:
# array([9, 5, 0, 4, 3, 6, 1, 2, 8, 7], dtype=int64)

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %% [markdown]
# # Outlier removal

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))

new_df=df [(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (149, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
(1/158)
# Out:
# 0.006329113924050633

# %%
#8 rows are deleted due to outliers

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#standard error,family,trust,and generosity are highly skewed datas

# %%
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.890608
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.180922
# Generosity                       0.650767
# Dystopia Residual               -0.238911
# dtype: float64

# %%
collist=df.columns.values
ncol=10
nrows=7

# %%
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sn.distplot(df[collist[i]])

# %%
#standard error,family and trust are little skewed

# %%
x=new_df.drop("Happiness Score",axis=1)
y=new_df["Happiness Score"]

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
max_r_score=0
for r_state in range(41,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 86 is 0.9999652954166569

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.2640521 ,  1.30301762, -1.70523445, ...,  2.29108114,
#          0.58711486,  0.76366883],
#        [-0.42339609,  1.30301762, -1.68288147, ...,  0.03658475,
#          1.664233  ,  1.11591405],
#        [-0.88360924,  1.30301762, -1.66052849, ...,  2.74517207,
#          0.94362541,  0.71532407],
#        ...,
#        [-1.69446097,  0.63934142,  1.69241874, ..., -0.37202006,
#          1.12831302, -0.31479717],
#        [-1.40956712,  0.97117952,  1.7371247 , ..., -0.5342214 ,
#         -0.38441416, -0.92305596],
#        [-1.23424783,  0.97117952,  1.78183066, ..., -0.33977048,
#         -0.25446188, -0.54198322]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=86)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.11076977e-03, -4.05938380e-04, -3.92108786e-03, -1.21931624e-03,
#         3.93128075e-01,  2.48855834e-01,  2.44219953e-01,  1.48811489e-01,
#         1.15212055e-01,  1.20005904e-01,  5.21052182e-01])

# %%
lm.intercept_
# Out:
# 5.437870329309263

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999242573426784

# %%
pred=lm.predict(x_test)
print('predicted o/p:',pred)
print('actual o/p',y_test)
# Out:
# predicted o/p: [6.47423324 4.57329441 6.49543724 5.76166588 7.56112203 4.19379945
#  5.83841066 4.03020294 4.24863993 5.78141573 7.26675632 5.12598614
#  3.89304478 6.27264533 5.36630996 3.93398003 5.85446884 4.21003905
#  7.27770469 3.66523679 6.90601028 3.59242922 6.41692284 4.51597743
#  5.47645784 4.97166206 6.33662926 5.08258614 4.51769502 5.28688383
#  4.84630523 6.12629223 5.88330457]
# actual o/p 32     6.477
# 116    4.565
# 30     6.505
# 62     5.754
# 1      7.561
# 134    4.194
# 56     5.828
# 136    4.033
# 132    4.252
# 60     5.770
# 8      7.286
# 86     5.123
# 142    3.896
# 39     6.269
# 74     5.360
# 140    3.931
# 54     5.848
# 133    4.218
# 9      7.284
# 148    3.667
# 19     6.901
# 151    3.587
# 34     6.411
# 120    4.514
# 71     5.474
# 93     4.971
# 35     6.329
# 89     5.073
# 121    4.512
# 76     5.286
# 102    4.839
# 41     6.130
# 52     5.878
# Name: Happiness Score, dtype: float64

# %%
print('error:')
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:',mean_squared_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# mean absolute error: 0.005417456404634468
# mean squared error: 4.427472450241613e-05
# root mean squared error: 0.006653925495706736

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.9999636306276686

# %%
from sklearn.model_selection import cross_val_score
lmscores=cross_val_score(lm,x,y,cv=5)
print(lmscores)
print(lmscores.mean(),lmscores.std())
# Out:
# [0.99802661 0.99794998 0.99731488 0.99648005 0.99955038]
# 0.9978643817165391 0.0010094117086458544

# %%
from sklearn .linear_model import Lasso,Ridge, ElasticNet
ls=Lasso(alpha=.001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9998969230866963

# %%
ls.coef_
# Out:
# array([ 2.81028799e-04,  0.00000000e+00, -5.32488903e-02, -1.38426621e-03,
#         3.75354363e-01,  2.37931940e-01,  2.31968295e-01,  1.41994298e-01,
#         1.11142890e-01,  1.14670789e-01,  4.97257844e-01])

# %%
lscores=cross_val_score(ls,x,y,cv=5)
print(lscores)
print(lscores.mean(),lscores.std())
# Out:
# [0.98169811 0.99587468 0.99740967 0.9969706  0.998555  ]
# 0.9941016094917074 0.0062609536495903525

# %%
rd=Ridge(alpha=.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9999242573281644

# %%
rd.coef_
# Out:
# array([ 1.11085559e-03, -4.04774525e-04, -3.95967690e-03, -1.21990964e-03,
#         3.93113628e-01,  2.48847415e-01,  2.44211283e-01,  1.48806204e-01,
#         1.15209094e-01,  1.20001777e-01,  5.21033912e-01])

# %%
rdscores=cross_val_score(rd,x,y,cv=5)
print(rdscores)
print(rdscores.mean(),rdscores.std())
# Out:
# [0.99802485 0.99794936 0.99731544 0.99648052 0.99955004]
# 0.9978640411495323 0.0010090410646002872

# %%
enr=ElasticNet(alpha=.001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.9999027787916489
# array([ 7.41887685e-04,  4.26664273e-04, -4.97173955e-02, -1.63845711e-03,
#         3.76356838e-01,  2.38781735e-01,  2.33318758e-01,  1.42507508e-01,
#         1.11553934e-01,  1.15081308e-01,  4.99143419e-01])

# %%
enrscores=cross_val_score(enr,x,y,cv=5)
print(enrscores)
print(enrscores.mean(),enrscores.std())
# Out:
# [0.98800833 0.99617587 0.9974713  0.99668276 0.99863227]
# 0.9953941067275288 0.0037847574499944177

# %%
from sklearn.svm import SVR
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
svr=SVR(kernel='poly')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.997642120682782
# 0.974648390180207
# 0.9869085321319447

# %%
svrscores=cross_val_score(svr,x,y,cv=5)
print(svrscores)
print(svrscores.mean(),svrscores.std())
# Out:
# [-12.88749504   0.31094674   0.79789833  -0.98865597  -6.18094278]
# -3.789649742790573 5.180639463805132

# %%
#ridge regression method gives a better accuracy score than others.so we choose ridge regression method for this analysis

# %%
import joblib
joblib.dump(rd,'rd_happiness.pkl')
# Out:
# ['rd_happiness.pkl']
